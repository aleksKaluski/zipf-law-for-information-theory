# %%
# basic
from importlib import reload
import numpy as np
import pandas as pd
import os
import ast

# aesthetics
import matplotlib.pyplot as plt

# nlp-related
import spacy
import gensim
from wordcloud import WordCloud

# %%
df = pd.read_pickle('dfs/preprocessed-cleaned-df.pkl')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   prompt           214 non-null    object
#  1   professor        214 non-null    object
#  2   student          214 non-null    object
#  3   prompt_clean     214 non-null    object
#  4   professor_clean  214 non-null    object
#  5   student_clean    214 non-null    object
# dtypes: object(6)
# memory usage: 10.2+ KB
#                                               prompt  \
# 0  ['You happen to know that Tim and Harry have r...
# 1  ['You happen to know that Tim and Harry have r...
# 2  ['You happen to know that Tim and Harry have r...
# 3  ['You happen to know that Tim and Harry have r...
# 4  ['\n Even if it is true that we routinely rely...
#
#                                            professor  \
# 0  That's a great question! You see, our brains a...
# ...

# %%
texts = df['prompt_clean'].apply(ast.literal_eval)
texts
# Out:
# 0      [happen, know, tim, harry, recently, terrible,...
# 1      [happen, know, tim, harry, recently, terrible,...
# 2      [happen, know, tim, harry, recently, terrible,...
# 3      [happen, know, tim, harry, recently, terrible,...
# 4      [true, routinely, rely, abductive, reasoning, ...
#                              ...
# 209    [distance, thing, place, distance, idea, truly...
# 210    [distance, thing, place, distance, idea, truly...
# 211    [distance, thing, place, distance, idea, truly...
# 212    [distance, thing, place, distance, idea, truly...
# 213    [distance, thing, place, distance, idea, truly...
# Name: prompt_clean, Length: 214, dtype: object

# %%
# since gensim expects a list single list, we need to
# texts = df['prompt_clean'].tolist() + df['professor_clean'].tolist() + df['student_clean'].tolist() # tokenized text

# unique tokens -> numeric ids
dic=gensim.corpora.Dictionary(texts)
bow_corpus = [dic.doc2bow(doc) for doc in texts] # BOW
