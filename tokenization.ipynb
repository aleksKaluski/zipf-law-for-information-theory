# %%
import pandas as pd
import spacy
from importlib import reload

# %%
from source import tokenizator as tk

# %%
df = pd.read_csv('dfs/preprocessed-df.csv', delimiter=';')
df.head()
# Out:
#                                               prompt  \
# 0  ['You happen to know that Tim and Harry have r...
# 1  ['You happen to know that Tim and Harry have r...
# 2  ['You happen to know that Tim and Harry have r...
# 3  ['You happen to know that Tim and Harry have r...
# 4  ['\n Even if it is true that we routinely rely...
#
#                                            professor  \
# 0  That's a great question! You see, our brains a...
# 1  Of course, you could be wrong! But here's the ...
# 2  Ah, great example! This is where the concept o...
# 3  Exactly! Our minds are wired to seek patterns ...
# 4  Well, my inquisitive student, that's a great q...
#
#                                              student
# 0  Professor, I was thinking about how I conclude...
# 1  But isn't that just an assumption? I mean, I c...
# 2  That makes sense, I guess. But what about case...
# 3  Yeah, I think so. It's like, our brains are al...
# 4  Professor Phil, do we always choose the simple...

# %%
nlp = spacy.load('en_core_web_sm')

# %%
reload(tk)
tk.tag_df_with_spacy(df=df, nlp= nlp, column_names=['prompt', 'professor'])
# Out:
# Cleaning column "prompt"...
# Cleaning column "professor"...
#                                                prompt  \
# 0   ['You happen to know that Tim and Harry have r...
# 1   ['You happen to know that Tim and Harry have r...
# 2   ['You happen to know that Tim and Harry have r...
# 3   ['You happen to know that Tim and Harry have r...
# 4   ['\n Even if it is true that we routinely rely...
# 5   ['\n Even if it is true that we routinely rely...
# 6   ['\n Even if it is true that we routinely rely...
# 7   ['\n Even if it is true that we routinely rely...
# 8   ['\n The Buddha’s discourses collected in the ...
# 9   ['\n The Buddha’s discourses collected in the ...
# 10  ['\n The Buddha’s discourses collected in the ...
# 11  ['\n The Buddha’s discourses collected in the ...
# 12  ['\n The Buddha’s discourses collected in the ...
# 13  ['What is an ability? On one reading, this que...
# 14  ['What is an ability? On one reading, this que...
# 15  ['What is an ability? On one reading, this que...
# 16  ['\n It will be helpful to begin by considerin...
# 17  ['\n It will be helpful to begin by considerin...
# 18  ['\n It will be helpful to begin by considerin...
# 19  ['\n It will be helpful to begin by considerin...
# 20  ['\n It will be helpful to begin by considerin...
#
#                                             professor  \
# 0   That's a great question! You see, our brains a...
# 1   Of course, you could be wrong! But here's the ...
# 2   Ah, great example! This is where the concept o...
# 3   Exactly! Our minds are wired to seek patterns ...
# 4   Well, my inquisitive student, that's a great q...
# 5   Ah, an astute observation! Yes, when dealing w...
# 6   Ah, your colleague is onto something! Yes, sim...
# 7   Ah, excellent question! The critics of abducti...
# 8   Ah, you're onto something. Think of a movie. A...
# 9   That's a great point. The Abhidharma philosoph...
# 10  The Abhidharma would say that by analyzing rea...
# 11  Ah, that's where things get really interesting...
# 12  The Abhidharma would say that the ultimate goa...
# 13  That's a great question. Think of it like this...
# 14  Exactly! That's the challenge. Some philosophe...
# 15  Well, I think the latter might be more fruitfu...
# 16  That's an intriguing question. To explore this...
# 17  That's a clever distinction. I'd argue that in...
# 18  Excellent observation! While related, disposit...
# 19  Ah, now we're entering a debate that has been ...
# 20  Exactly! Recognizing the ontological diversity...
#
#                                               student  \
# 0   Professor, I was thinking about how I conclude...
# 1   But isn't that just an assumption? I mean, I c...
# 2   That makes sense, I guess. But what about case...
# 3   Yeah, I think so. It's like, our brains are al...
# 4   Professor Phil, do we always choose the simple...
# 5   That's a great point, Professor. But what abou...
# 6   That reminds me of a conversation I had with a...
# 7   I see what you mean, Professor. It's like we n...
# 8   Professor Phil, I was reading this book about ...
# 9   But if everything is made up of these fleeting...
# 10  I think I see. So it's like the river is made ...
# 11  That makes sense, I think. But what about the ...
# 12  Okay, I think I'm starting to get it. But what...
# 13  Professor Phil, I've been wondering, how do we...
# 14  Hmm, I never thought about it that way. But do...
# 15  That makes sense. So, are we trying to come up...
# 16  Professor, I've been thinking about abilities ...
# 17  That makes sense, but what about natural pheno...
# 18  I'm starting to see how these concepts are int...
# 19  That helps clarify the distinction. However, I...
# 20  That makes sense. It seems to me that this has...
#
#                                          prompt_clean  \
# 0   [happen, know, Tim, Harry, recently, terrible,...
# 1   [happen, know, Tim, Harry, recently, terrible,...
# 2   [happen, know, Tim, Harry, recently, terrible,...
# 3   [happen, know, Tim, Harry, recently, terrible,...
# 4   [true, routinely, rely, abductive, reasoning, ...
# 5   [true, routinely, rely, abductive, reasoning, ...
# 6   [true, routinely, rely, abductive, reasoning, ...
# 7   [true, routinely, rely, abductive, reasoning, ...
# 8   [Buddha, discourse, collect, Āgamas, Nikāyas, ...
# 9   [Buddha, discourse, collect, Āgamas, Nikāyas, ...
# 10  [Buddha, discourse, collect, Āgamas, Nikāyas, ...
# 11  [Buddha, discourse, collect, Āgamas, Nikāyas, ...
# 12  [Buddha, discourse, collect, Āgamas, Nikāyas, ...
# 13  [ability, reading, question, demand, theory, a...
# 14  [ability, reading, question, demand, theory, a...
# 15  [ability, reading, question, demand, theory, a...
# 16  [helpful, begin, consider, topic, relate, nomi...
# 17  [helpful, begin, consider, topic, relate, nomi...
# 18  [helpful, begin, consider, topic, relate, nomi...
# 19  [helpful, begin, consider, topic, relate, nomi...
# 20  [helpful, begin, consider, topic, relate, nomi...
#
#                                       professor_clean
# 0   [great, question, brain, wire, look, plausible...
# 1   [course, wrong, thing, reasoning, base, probab...
# 2   [great, example, concept, abduction, come, abd...
# 3   [exactly, mind, wire, seek, pattern, explanati...
# 4   [inquisitive, student, great, question, mind, ...
# 5   [astute, observation, yes, deal, incomplete, d...
# 6   [colleague, yes, simplicity, lead, lack, criti...
# 7   [excellent, question, critic, abduction, like,...
# 8   [think, movie, movie, appear, continuous, flow...
# 9   [great, point, Abhidharma, philosopher, imperm...
# 10  [Abhidharma, analyze, reality, constituent, dh...
# 11  [thing, interesting, Abhidharma, philosopher, ...
# 12  [Abhidharma, ultimate, goal, understand, liber...
# 13  [great, question, think, like, ability, play, ...
# 14  [exactly, challenge, philosopher, argue, abili...
# 15  [think, fruitful, try, pin, exact, definition,...
# 16  [intriguing, question, explore, idea, let, con...
# 17  [clever, distinction, argue, case, like, river...
# 18  [excellent, observation, relate, disposition, ...
# 19  [enter, debate, ongoing, philosophical, circle...
# 20  [exactly, recognize, ontological, diversity, p...
